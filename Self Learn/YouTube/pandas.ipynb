# %%
import pandas as pd

# %%
s = pd.Series([10,20,30,40,50])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s.name

# %%
print(s.name)
# Out:
# None

# %%
s.name = 'numbers'

# %%
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: numbers, dtype: int64

# %%
s[0]
# Out:
# np.int64(10)

# %%
s[0:3]
# Out:
# 0    10
# 1    20
# 2    30
# Name: numbers, dtype: int64

# %%
s[2:4]
# Out:
# 2    30
# 3    40
# Name: numbers, dtype: int64

# %%
s.iloc[3]
# Out:
# np.int64(40)

# %%
s.iloc[[0,2,4]]
# Out:
# 0    10
# 2    30
# 4    50
# Name: numbers, dtype: int64

# %%
index = ['a','b','c','d','e']
s.index = index

# %%
s
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# Name: numbers, dtype: int64

# %%
s[0]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2524\243613605.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[0]
# np.int64(10)

# %%
s['a']
# Out:
# np.int64(10)

# %%
s.iloc[1]
# Out:
# np.int64(20)

# %%
s.loc['b']
# Out:
# np.int64(20)

# %%
s[0:3]
# Out:
# a    10
# b    20
# c    30
# Name: numbers, dtype: int64

# %%
s['a':'d']
# Out:
# a    10
# b    20
# c    30
# d    40
# Name: numbers, dtype: int64

# %%
s.loc[['a','b','d']]
# Out:
# a    10
# b    20
# d    40
# Name: numbers, dtype: int64
