# %% [markdown]
# NumPy is used to work with arrays. The array object in NumPy is called ndarray.

# %% [markdown]
# We can create a NumPy ndarray object by using the array() function.

# %%
import numpy as np

arr = np.array([1,2,3,4,5,6,7,7])

arr,type(arr)
# Out:
# (array([1, 2, 3, 4, 5, 6, 7, 7]), numpy.ndarray)

# %% [markdown]
# To create an ndarray, we can pass a list, tuple or any array-like object into the array() method, and it will be converted into an ndarray

# %%
arr2 = np.array((1,2,3,4,5,6))

arr2,type(arr2)
# Out:
# (array([1, 2, 3, 4, 5, 6]), numpy.ndarray)

# %%
arr3 = np.array(100)

arr,type(arr)
# Out:
# (array([1, 2, 3, 4, 5, 6, 7, 7]), numpy.ndarray)

# %% [markdown]
# | Code              | Array Type   | Dimension | Shape  |
# | ----------------- | ------------ | --------- | ------ |
# | `np.array(100)`   | Scalar array | 0D        | `()`   |
# | `np.array([100])` | Vector       | 1D        | `(1,)` |

# %%
arr3.shape
# Out:
# ()

# %%
arr3.ndim
# Out:
# 0

# %% [markdown]
# ## 1-D Arrays

# %%
arr4 = np.array([100])

arr4,type(arr4),arr4.shape,arr4.ndim
# Out:
# (array([100]), numpy.ndarray, (1,), 1)

# %% [markdown]
# ## 2-D Arrays

# %%
arr5 = np.array([[1,2,4,5,6],[9,8,7,6,1]])

arr5
# Out:
# array([[1, 2, 4, 5, 6],
#        [9, 8, 7, 6, 1]])

# %% [markdown]
# ## 3-D arrays

# %%
arr6 = np.array([[[1,2,3],[4,5,6]],[[6,7,8],[1,5,9]]])

arr6
# Out:
# array([[[1, 2, 3],
#         [4, 5, 6]],
#
#        [[6, 7, 8],
#         [1, 5, 9]]])

# %%
arr6.ndim
# Out:
# 3

# %%
arr7 = np.array([1,2,3,4],ndmin=8)

arr7,arr7.ndim
# Out:
# (array([[[[[[[[1, 2, 3, 4]]]]]]]]), 8)

# %%
import numpy as np

# %%
arr1 = np.array([1, 2, 3, 4])
print(arr1, arr1.dtype)
print(arr1.dtype)
# Out:
# [1 2 3 4] int64
# int64

# %%
arr2 = np.zeros((2,3))  # 2 rows, 3 columns
arr3 = np.ones((2,3),dtype=int)


arr2,arr3
# Out:
# (array([[0., 0., 0.],
#         [0., 0., 0.]]),
#  array([[1, 1, 1],
#         [1, 1, 1]]))

# %%
arr4 = np.arange(0,10,3)

arr4
# Out:
# array([0, 3, 6, 9])

# %%
arr5 = np.linspace(0,1,5)
arr5
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])
