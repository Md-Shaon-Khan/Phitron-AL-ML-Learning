# %%
import numpy as np

# %%
arr = np.array([10,3,5,7,2])

# %%
print(np.sort(arr))
# Out:
# [ 2  3  5  7 10]

# %%
arr
# Out:
# array([10,  3,  5,  7,  2])

# %%
print(np.argsort(arr))
# Out:
# [4 1 2 3 0]

# %%
print(np.argmax(arr))
# Out:
# 0

# %%
print(np.max(arr))
# Out:
# 10

# %%
print(np.where(arr > 5))
# Out:
# (array([0, 3]),)
