# %%
import numpy as np

# %%
a = np.array([[1,2],
              [3,4]])
b = np.array([[5,6],
              [7,8]])

# %%
h = np.concatenate((a,b),axis=0)

# %%
h,h.shape
# Out:
# (array([[1, 2],
#         [3, 4],
#         [5, 6],
#         [7, 8]]),
#  (4, 2))

# %%
v = np.concatenate((a,b),axis=1)
v,v.shape
# Out:
# (array([[1, 2, 5, 6],
#         [3, 4, 7, 8]]),
#  (2, 4))

# %%
s = np.stack((a,b),axis=0)

# %%
s,s.ndim,s.shape
# Out:
# (array([[[1, 2],
#          [3, 4]],
#
#         [[5, 6],
#          [7, 8]]]),
#  3,
#  (2, 2, 2))

# %%
c = np.column_stack((a,b))
c
# Out:
# array([[1, 2, 5, 6],
#        [3, 4, 7, 8]])
