# %%
import pandas as pd

# %%
users = pd.DataFrame({
    'user_id': [1, 2, 3, 4],
    'name': ['Alice', 'Bob', 'Charlie', 'David'],
    'age': [25, 30, 35, 28]
})

orders = pd.DataFrame({
    'user_id': [1, 2, 2, 5],   
    'amount': [100, 200, 150, 300],
    'product': ['A', 'B', 'A', 'C']
})


users
# Out:
#    user_id     name  age
# 0        1    Alice   25
# 1        2      Bob   30
# 2        3  Charlie   35
# 3        4    David   28

# %%
orders
# Out:
#    user_id  amount product
# 0        1     100       A
# 1        2     200       B
# 2        2     150       A
# 3        5     300       C

# %% [markdown]
# ![image.png](attachment:image.png)
