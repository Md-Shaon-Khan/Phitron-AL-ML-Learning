# %%
import math

print(math.pi)
print(math.e)
print(math.sqrt(25))
print(math.pow(2,5))
print(math.floor(4.6))
print(math.ceil(3.3))
print(math.fabs(-6))
print(math.factorial(5))
# Out:
# 3.141592653589793
# 2.718281828459045
# 5.0
# 32.0
# 4
# 4
# 6.0
# 120

# %%
import random

print(random.randint(1,10))
print(random.random())
print(random.uniform(1.5,5.5))

name = ['Shaon','Ayan','Shahadat','Mahi','Nayem','Nahid']

print(random.choice(name))
print(random.sample(name,2))

random.shuffle(name)
print(name)
# Out:
# 5
# 0.12944138590764798
# 5.091173334629197
# Shaon
# ['Nahid', 'Shaon']
# ['Nayem', 'Mahi', 'Shaon', 'Shahadat', 'Nahid', 'Ayan']

# %%
import os

print(os.getcwd())
print(os.listdir())
print(os.path.exists('math_mod_imp.ipynb'))
print(os.path.exists('test.ipynb'))
# Out:
# f:\Jupyter_Projects\Phitron AL ML\Self Learn\Python\Modules & Imports
# ['math_mod_imp.ipynb']
# True
# False

# %%
os.mkdir('Test_Folder')

# %%
os.rename('math_mod_imp.ipynb','new_name.ipynb')
