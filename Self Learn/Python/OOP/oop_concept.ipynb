# %%
class Student:
  pass

s1 = Student()
s2 = Student()

print(type(s1))
print(s1)
# Out:
# <class '__main__.Student'>
# ...

# %%
class Student:
  def __init__(self,name,age,grade):
    self.name = name
    self.age = age
    self.grade = grade
    
s1 = Student('Shaon Khan',22,'A')
s2 = Student('Ayan Khan',9,'B')

print(s1.name)
print(s2.age)
print(s1.grade)
# Out:
# Shaon Khan
# 9
# A

# %%
class Student:
  def __init__(self,name,age,grade):
    self.name = name
    self.age = age
    self.grade = grade
    
  def introduce(self):
    print(f"Hi! I'm {self.name}, Age: {self.age}, Grade: {self.grade}")
  
  def is_passing(self):
    return self.grade in ('A','B','C')
  
s1 = Student('Shaon',23,'A')
s2 = Student('Khan',23,'D')

s1.introduce()
s2.introduce()

print(s1.is_passing())
print(s2.is_passing())
# Out:
# Hi! I'm Shaon, Age: 23, Grade: A
# Hi! I'm Khan, Age: 23, Grade: D
# True
# False

# %%
class Student3:
  school = 'Jahangirnagar University'
  
  def __init__(self,name,grade):
    self.name = name
    self.grade = grade

s1 = Student3('Shaon Khan','A')
s2 = Student3('Ayan Khan','P')

print(s1.name)
print(s2.name)
# Out:
# Shaon Khan
# Ayan Khan

# %%
print(s1.school)
print(s2.school)
# Out:
# Jahangirnagar University
# Jahangirnagar University

# %%
print(Student3.school)
# Out:
# Jahangirnagar University

# %%
Student3.school = 'JU'

print(s1.school)
print(s2.school)
# Out:
# JU
# JU

# %%
class BankAccount:
  def __init__(self,owner,balance):
    self.owner = owner
    self.__balance = balance
  def deposit(self,amount):
    if amount > 0:
      self.__balance += amount
      print(f"Deposited {amount}. New Balance: {self.__balance}")
  
  def withdraw(self, amount):
    if amount > self.__balance:
      print("Insufficient funds!")
    else:
      self.__balance -= amount
      print(f"Withdrawn {amount}. New Balance: {self.__balance}")
  def get_balance(self):
    return self.__balance

acc = BankAccount('Alice',1000)
acc.deposit(500)
acc.withdraw(200)

print(acc.get_balance())
# Out:
# Deposited 500. New Balance: 1500
# Withdrawn 200. New Balance: 1300
# 1300

# %%
class Animal:
    def __init__(self, name, age):
        self.name = name
        self.age  = age

    def eat(self):
        print(f"{self.name} is eating ")

    def sleep(self):
        print(f"{self.name} is sleeping ")



class Dog(Animal):
    def __init__(self, name, age, breed):
        super().__init__(name, age)   
        self.breed = breed

    def bark(self):
        print(f"{self.name} says: Woof! ")


class Cat(Animal):
    def __init__(self, name, age, color):
        super().__init__(name, age)
        self.color = color

    def meow(self):
        print(f"{self.name} says: Meow! ")


dog = Dog("Rex",   3, "Labrador")
cat = Cat("Kitty", 2, "White")

dog.eat()    
dog.sleep()   
dog.bark()

cat.eat()     
cat.meow()
# Out:
# Rex is eating
# Rex is sleeping
# Rex says: Woof!
# Kitty is eating
# Kitty says: Meow!

# %%
class Shape:
  def area(self):
    pass

class Circle(Shape):
  def __init__(self,radius):
    self.radius = radius
  
  def area(self):
    return 3.1416 * (self.radius ** 2)

class Rectangle(Shape):
  def __init__(self,width,height):
    self.width = width
    self.height = height
  
  def area(self):
    return self.width * self.height

class Triangle(Shape):
  def __init__(self,base,height):
    self.base = base
    self.height = height
  
  def area(self):
    return 0.5 * self.base * self.height

shapes = [Circle(5), Rectangle(4,6), Triangle(3,5)]

Cir = Circle(5)
print(Cir.area())

Tri = Triangle(3,6)
print(Tri.area())

Rec = Rectangle(4,6)
print(Rec.area())
# Out:
# 78.53999999999999
# 9.0
# 24

# %%
shapes = [Circle(5), Rectangle(4, 6), Triangle(3, 8)]

for shape in shapes:
    print(f"{shape.__class__.__name__} area: {shape.area():.2f}")
# Out:
# Circle area: 78.54
# Rectangle area: 24.00
# Triangle area: 12.00
