# %%
dic = {"Name": "Shaon Khan", "Age": 22, "University" : "JU", "number": 1633040670}

dic
# Out:
# {'Name': 'Shaon Khan', 'Age': 22, 'University': 'JU', 'number': 1633040670}

# %%
dic.get("marks")

# %%
dic.get("marks","NULL")
# Out:
# 'NULL'

# %%
dic.get("Name","NULL")
# Out:
# 'Shaon Khan'

# %%
dic["math_marks"] = 88

dic
# Out:
# {'Name': 'Shaon Khan',
#  'Age': 22,
#  'University': 'JU',
#  'number': 1633040670,
#  'math_marks': 88}

# %%
dic.update({"ML_marks": 98})

dic
# Out:
# {'Name': 'Shaon Khan',
#  'Age': 22,
#  'University': 'JU',
#  'number': 1633040670,
#  'math_marks': 88,
#  'ML_marks': 98}

# %%
del dic["math_marks"]

# %%
dic
# Out:
# {'Name': 'Shaon Khan',
#  'Age': 22,
#  'University': 'JU',
#  'number': 1633040670,
#  'ML_marks': 98}

# %%
dic2 = dic.copy()

dic2
# Out:
# {'Name': 'Shaon Khan',
#  'Age': 22,
#  'University': 'JU',
#  'number': 1633040670,
#  'ML_marks': 98}

# %%
dic2.pop("ML_marks")
# Out:
# 98
