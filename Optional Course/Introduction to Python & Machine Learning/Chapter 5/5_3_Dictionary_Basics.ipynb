# %% [markdown]
# ## Dictionary

# %%
dic = {}

type(dic)
# Out:
# dict

# %%
dic = {"name": "Shaon Khan", "age": 22, "university" : "JU"}

type(dic), dic
# Out:
# (dict, {'name': 'Shaon Khan', 'age': 22, 'university': 'JU'})

# %%
dic["name"]
# Out:
# 'Shaon Khan'

# %%
dic["university"]
# Out:
# 'JU'

# %%
dic.get("age")
# Out:
# 22

# %%
dic["name"] = "Shaon"

dic
# Out:
# {'name': 'Shaon', 'age': 22, 'university': 'JU'}

# %%
dic = {"name":"Shaon Khan", "age": 22, "university" : "JU", "age": 100}

dic
# Out:
# {'name': 'Shaon Khan', 'age': 100, 'university': 'JU'}
