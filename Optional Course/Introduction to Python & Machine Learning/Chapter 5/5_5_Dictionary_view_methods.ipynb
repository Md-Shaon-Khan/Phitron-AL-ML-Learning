# %%
dic = {"Name": "Shaon Khan", "Age": 22, "University" : "JU", "number": 1633040670}

dic
# Out:
# {'Name': 'Shaon Khan', 'Age': 22, 'University': 'JU', 'number': 1633040670}

# %%
keys = dic.keys()

keys
# Out:
# dict_keys(['Name', 'Age', 'University', 'number'])

# %%
dic["math"] = 100

keys
# Out:
# dict_keys(['Name', 'Age', 'University', 'number', 'math'])

# %%
values = dic.values()

values
# Out:
# dict_values(['Shaon Khan', 22, 'JU', 1633040670, 100])

# %%
item = dic.items()

item
# Out:
# dict_items([('Name', 'Shaon Khan'), ('Age', 22), ('University', 'JU'), ('number', 1633040670), ('math', 100)])

# %%
for key,value in dic.items():
  print(f"Key: {key} and Value: {value}")
# Out:
# Key: Name and Value: Shaon Khan
# Key: Age and Value: 22
# Key: University and Value: JU
# Key: number and Value: 1633040670
# Key: math and Value: 100
