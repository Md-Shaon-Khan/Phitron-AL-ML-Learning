# %% [markdown]
# ## Sets

# %%
A = {1,2,3}

type(A)
# Out:
# set

# %%
A
# Out:
# {1, 2, 3}

# %%
B = {}

type(B)
# Out:
# dict

# %%
A = []

type(A)
# Out:
# list

# %%
A = ()

type(A)
# Out:
# tuple

# %%
B = set()

type(B)
# Out:
# set

# %%
B = {1,2,3,4,1,7,8,9}

B
# Out:
# {1, 2, 3, 4, 7, 8, 9}

# %%
B.add(5)

# %%
B
# Out:
# {1, 2, 3, 4, 5, 7, 8, 9}

# %%
if 5 in B:
    print("5 in present")
else:
    print("Not present")
# Out:
# 5 in present

# %%
sum = 0
for element in B:
    print(element,end=" ")
    sum += element
print(sum)
# Out:
# 1 2 3 4 5 7 8 9 39

# %%
B.pop()
# Out:
# 1

# %%
B
# Out:
# {2, 3, 4, 5, 7, 8, 9}

# %%
B.remove(5)

# %%
B
# Out:
# {2, 3, 4, 7, 8, 9}

# %%
A = {2,3,9,12,19}

A
# Out:
# {2, 3, 9, 12, 19}

# %%
s = A.union(B)

# %%
s
# Out:
# {2, 3, 4, 7, 8, 9, 12, 19}

# %%
i = A.intersection(B)
i
# Out:
# {2, 3, 9}

# %%
A.isdisjoint(B)
# Out:
# False

# %%
A.issubset(B)
# Out:
# False
