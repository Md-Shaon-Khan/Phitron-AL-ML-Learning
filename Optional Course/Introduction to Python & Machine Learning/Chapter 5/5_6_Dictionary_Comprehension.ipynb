# %%
square = {x:x**2 for x in range(1,11) if x%2==1}
square
# Out:
# {1: 1, 3: 9, 5: 25, 7: 49, 9: 81}

# %%
name = ["Shaon", "Shahadat", "Nayem", "Raunaq", "Kuasha", "Nahid"]
marks = [90, 75, 45, 80, 85, 78]

dic = {nam:mark for nam,mark in zip(name,marks) if mark > 50}

dic
# Out:
# {'Shaon': 90, 'Shahadat': 75, 'Raunaq': 80, 'Kuasha': 85, 'Nahid': 78}
