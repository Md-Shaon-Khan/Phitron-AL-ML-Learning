# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## List

# %%
lst = [10,20,30,40,50]

lst, type(lst)
# Out:
# ([10, 20, 30, 40, 50], list)

# %%
lst[0], lst[-1], lst[1:4],lst[::2], lst[::-1]
# Out:
# (10, 50, [20, 30, 40], [10, 30, 50], [50, 40, 30, 20, 10])

# %%
lst.append(60)

# %%
lst
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
lst.insert(0,1)

# %%
lst
# Out:
# [1, 10, 20, 30, 40, 50, 60]

# %%
lst.remove(1)

# %%
lst.pop()
# Out:
# 60

# %%
lst
# Out:
# [10, 20, 30, 40, 50]

# %%
lst.append(10)

# %%
lst.remove(10)

# %%
lst
# Out:
# [20, 30, 40, 50, 10]

# %%
lst.sort()

# %%
lst
# Out:
# [10, 20, 30, 40, 50]

# %%
lst.reverse()

# %%
lst
# Out:
# [50, 40, 30, 20, 10]

# %%
lst = [1,2,1,6,7,9,4]
lst.reverse()

# %%
lst
# Out:
# [4, 9, 7, 6, 1, 2, 1]

# %%
lst.count(1)
# Out:
# 2

# %%
lst.index(1)
# Out:
# 4

# %% [markdown]
# ## Tuple

# %%
tpl = (10,20,30,30,40,50)

# %%
tpl
# Out:
# (10, 20, 30, 30, 40, 50)

# %%
type(tpl)
# Out:
# tuple

# %%
tpl[0], tpl[-1], tpl[1:4],tpl[::2], tpl[::-1]
# Out:
# (10, 50, (20, 30, 30), (10, 30, 40), (50, 40, 30, 30, 20, 10))

# %%
tpl.count(30)
# Out:
# 2

# %%
tpl.index(30)
# Out:
# 2

# %%
len(tpl)
# Out:
# 6

# %%
try:
    tpl[0] = 100
except TypeError as e:
    print(e)
# Out:
# 'tuple' object does not support item assignment

# %% [markdown]
# ## Set

# %%
s1 = {10,20,30,40,50}

s2 = {30,30,40,50,60,70,80}

# %%
s1,s2
# Out:
# ({10, 20, 30, 40, 50}, {30, 40, 50, 60, 70, 80})

# %%
s1.add(50)

# %%
s1.pop()
# Out:
# 50

# %%
s1
# Out:
# {10, 20, 30, 40}

# %%
s1.pop()
# Out:
# 20

# %%
s1
# Out:
# {10, 30, 40}

# %%
s1.remove(30)

# %%
s1
# Out:
# {10, 40}

# %%
s1.union(s2)
# Out:
# {10, 30, 40, 50, 60, 70, 80}

# %%
s1 | s2
# Out:
# {10, 30, 40, 50, 60, 70, 80}

# %%
s1 & s2
# Out:
# {40}

# %%
s1.intersection(s2)
# Out:
# {40}

# %%
s1-s2
# Out:
# {10}

# %%
s1.difference(s2)
# Out:
# {10}

# %%
s2.difference(s1)
# Out:
# {30, 50, 60, 70, 80}

# %%
s1 ^ s2
# Out:
# {10, 30, 50, 60, 70, 80}

# %%
s1 <= s2
# Out:
# False

# %%
s2 <= s1
# Out:
# False

# %%
s1
# Out:
# {10, 40}

# %%
s1.remove(10)

# %%
s1 <= s2
# Out:
# True

# %%
s2 >= s1
# Out:
# True

# %%
s1 >= s2
# Out:
# False

# %% [markdown]
# ## Dictionary

# %%
student = {"name": "Shaon", "age": 22, "grade": "A+"}

# %%
student
# Out:
# {'name': 'Shaon', 'age': 22, 'grade': 'A+'}

# %%
type(student)
# Out:
# dict

# %%
student["name"] = "Nayem"

# %%
student
# Out:
# {'name': 'Nayem', 'age': 22, 'grade': 'A+'}

# %%
student.update({"name2": "Shaon"})

# %%
student
# Out:
# {'name': 'Nayem', 'age': 22, 'grade': 'A+', 'name2': 'Shaon'}

# %%
student['score'] = 95

# %%
student
# Out:
# {'name': 'Nayem', 'age': 22, 'grade': 'A+', 'name2': 'Shaon', 'score': 95}

# %%
student.pop('name')
# Out:
# 'Nayem'
