# %%
count = 1

while count < 10:
  print(count,"Hello World!")
  count += 1
# Out:
# 1 Hello World!
# 2 Hello World!
# 3 Hello World!
# 4 Hello World!
# 5 Hello World!
# 6 Hello World!
# 7 Hello World!
# 8 Hello World!
# 9 Hello World!

# %%
count
# Out:
# 10
