# %%
raining = True
muddy = False

if raining == True:
  print("Rain coat is necessary")
  print("Caution! It's raining")
  
  if muddy == True:
    print("Wear rain boots")
  elif muddy == False:
    print("Wear normal shoes")
else:
  print("Go without a rain coat")
  print("This is a sunny day")
# Out:
# Rain coat is necessary
# Caution! It's raining
# Wear normal shoes

# %%
taka = int(input())

if taka > 800:
  print("I will go to New Market at Savar")
elif taka > 500:
  print("I will buy a notebook")
else:
  print("I will save money")
# Out:
# I will save money

# %%
taka = int(input())
raining = bool(input())

if raining == True and taka > 800:
  print("I will go to New Market at Savar") 
elif raining == True and taka > 500:
  print("I will buy a notebook")
else:
  print("I will save money")
# Out:
# I will buy a notebook
