# %%
n = int(input())
target = float(input())

sum = 0
for i in range(n):
    a = float(input())
    sum += a

avg = sum / n


if avg <= target:
    print("PASS")
else:
    print("RETRY")
# Out:
#  5
#  0.40
#  0.45
#  0.42
#  0.39
#  0.41
#  0.44
# RETRY
