# %%
t = int(input())

for _ in range(t):
    s = input().strip()
    if '010' in s or '101' in s:
        print("Good")
    else:
        print("Bad")
# Out:
#  3
#  122
# Bad
#  101010111
# Good
#  345
# Bad
