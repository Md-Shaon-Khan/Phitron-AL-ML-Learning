# %% [markdown]
# String Methods

# %%
string = "Welcome to MathMania"

len(string)
# Out:
# 20

# %%
"to" in string
# Out:
# True

# %%
"To" in string
# Out:
# False

# %%
"Welcome to" in string
# Out:
# True

# %%
string = string.lower()

"welcome" in string
# Out:
# True

# %%
string
# Out:
# 'welcome to mathmania'

# %%
string = string.upper()

string
# Out:
# 'WELCOME TO MATHMANIA'

# %%
string.capitalize()
# Out:
# 'Welcome to mathmania'

# %%
string
# Out:
# 'WELCOME TO MATHMANIA'

# %%
index = string.find("MATHMANIA")

# %%
index
# Out:
# 11

# %%
string.find("WELCOME")
# Out:
# 0

# %%
string.rfind("WELCOME")
# Out:
# 0

# %%
string
# Out:
# 'WELCOME TO MATHMANIA'

# %%
last = string.rfind("WELCOME")

last
# Out:
# 0

# %%
count = string.count("A")

count
# Out:
# 3

# %%
string += " " + string

string
# Out:
# 'WELCOME TO MATHMANIA WELCOME TO MATHMANIA'

# %%
string.replace("MATHMANIA","WRESTLEMANIA")
# Out:
# 'WELCOME TO WRESTLEMANIA WELCOME TO WRESTLEMANIA'

# %%
text = "Machine Learning Engineer"
text.split()
# Out:
# ['Machine', 'Learning', 'Engineer']

# %%
words = ['Machine', 'Learning']; " ".join(words)
# Out:
# 'Machine Learning'

# %%
text = "   hello   "
text.strip()
# Out:
# 'hello'

# %%
text = "machine learning"
text.startswith("machine")
# Out:
# True

# %%
text = "report.pdf"
text.endswith(".pdf")
# Out:
# True

# %%
text = "Machine Learning"
text.index("Learning")
# Out:
# 8

# %%
text = "machine learning engineer"
text.title()
# Out:
# 'Machine Learning Engineer'

# %%
text = "Machine Learning"
text.swapcase()
# Out:
# 'mACHINE lEARNING'

# %%
text = "AI\nMachine Learning\nDeep Learning"
text.splitlines()
# Out:
# ['AI', 'Machine Learning', 'Deep Learning']

# %%
text = "Python"
text.isalpha()
# Out:
# True
