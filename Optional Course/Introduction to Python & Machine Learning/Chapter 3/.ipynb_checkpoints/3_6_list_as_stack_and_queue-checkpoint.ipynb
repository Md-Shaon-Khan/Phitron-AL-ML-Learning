# %%
numbers = list(map(int,input().split()))

numbers
# Out:
#  1 7 2 2 9 5 8 6 10
# [1, 7, 2, 2, 9, 5, 8, 6, 10]

# %%
numbers.sort()

# %%
numbers
# Out:
# [1, 2, 2, 5, 6, 7, 8, 9, 10]

# %%
numbers.sort(reverse=True)

numbers
# Out:
# [10, 9, 8, 7, 6, 5, 2, 2, 1]

# %%
numbers.reverse()

# %%
numbers
# Out:
# [1, 2, 2, 5, 6, 7, 8, 9, 10]

# %%
numbers = numbers[::-1]

numbers
# Out:
# [10, 9, 8, 7, 6, 5, 2, 2, 1]

# %%
numbers.sort()

# %%
numbers
# Out:
# [1, 2, 2, 5, 6, 7, 8, 9, 10]

# %% [markdown]
# ## List as Stack

# %%
numbers.pop()
numbers
# Out:
# [1, 2, 2, 5, 6, 7, 8, 9]

# %%
numbers.pop()
# Out:
# 9

# %%
numbers
# Out:
# [1, 2, 2, 5, 6, 7, 8]

# %%
stack = []

stack.append(1)
stack.append(2)
stack.append(3)
stack.append(4)
stack.append(5)

stack
# Out:
# [1, 2, 3, 4, 5]

# %%
stack.pop()
# Out:
# 5

# %%
stack
# Out:
# [1, 2, 3, 4]

# %%
stack[-1]
# Out:
# 4

# %% [markdown]
# ## List as Queue

# %%
queue = []

queue.append(1)
queue.append(2)
queue.append(3)
queue.append(4)
queue.append(5)

queue
# Out:
# [1, 2, 3, 4, 5]

# %%
queue.pop(0)
# Out:
# 1

# %%
queue
# Out:
# [2, 3, 4, 5]

# %%
queue.pop(0)
# Out:
# 2

# %%
queue
# Out:
# [3, 4, 5]
