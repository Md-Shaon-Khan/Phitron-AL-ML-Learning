# %% [markdown]
# Spliting Joining, Formating

# %%
prompt = "What is WWE ?"

# %%
prompt = prompt.split()

prompt
# Out:
# ['What', 'is', 'WWE', '?']

# %%
prompt[0],prompt[1]
# Out:
# ('What', 'is')

# %%
type(prompt)
# Out:
# list

# %%
pro = "I@am@from@JU"

pro = pro.split("@")
pro
# Out:
# ['I', 'am', 'from', 'JU']

# %%
type(pro)
# Out:
# list

# %%
sentence = "__".join(pro)

# %%
sentence
# Out:
# 'I__am__from__JU'

# %%
type(sentence)
# Out:
# str

# %% [markdown]
# Formatted String

# %%
name = "Shaon"
age = 22
height = 5.649222

information = f"My name is {name}, age {age}, and height {height:.2}"
information
# Out:
# 'My name is Shaon, age 22, and height 5.6'

# %%
type(information)
# Out:
# str

# %%
model  = 0.87399

model_per = f"Model accuracy is {model:.2%}"
model_per
# Out:
# 'Model accuracy is 87.40%'
