# %% [markdown]
# List and List Methods

# %%
numbers = [100,20,50,23,89]

type(numbers)
# Out:
# list

# %%
numbers
# Out:
# [100, 20, 50, 23, 89]

# %% [markdown]
# Access

# %%
numbers[2]
# Out:
# 50

# %%
for i in range(len(numbers)):
    print(numbers[i]," ")
# Out:
# 100
# 20
# 50
# 23
# 89

# %%
numbers[2] = 99

numbers
# Out:
# [100, 20, 99, 23, 89]

# %%
new_list = numbers[0:3]

# %%
new_list
# Out:
# [100, 20, 99]

# %%
new_list = numbers[::-1]

# %%
new_list
# Out:
# [89, 23, 99, 20, 100]

# %%
numbers.append(111)

numbers
# Out:
# [100, 20, 99, 23, 89, 111]

# %%
numbers.insert(1,0)

# %%
numbers
# Out:
# [100, 0, 20, 99, 23, 89, 111]

# %%
numbers.insert(0,11)

# %%
numbers
# Out:
# [11, 100, 0, 20, 99, 23, 89, 111]

# %%
numbers.pop()
# Out:
# 111

# %%
numbers
# Out:
# [11, 100, 0, 20, 99, 23, 89]

# %%
numbers.remove(100)

# %%
numbers
# Out:
# [11, 0, 20, 99, 23, 89]

# %%
listt = ["Shaon",9.1,6.8,9,10,100,100,100,28,"Khan"]

listt
# Out:
# ['Shaon', 9.1, 6.8, 9, 10, 100, 100, 100, 28, 'Khan']

# %%
type(listt[0]), type(listt[1])
# Out:
# (str, float)

# %%
list2D = [[10,11,12,13],
          [100,111,123,156],
          [9,99,999,9999]]

# %%
list2D
# Out:
# [[10, 11, 12, 13], [100, 111, 123, 156], [9, 99, 999, 9999]]

# %%
list2D.append([0,1,2])

# %%
list2D
# Out:
# [[10, 11, 12, 13], [100, 111, 123, 156], [9, 99, 999, 9999], [0, 1, 2]]

# %%
list2D[0]
# Out:
# [10, 11, 12, 13]

# %%
list2D[0][1]
# Out:
# 11

# %%
for i in range(4):
    for j in range(3):
        print(list2D[i][j]," ")
# Out:
# 10
# 11
# 12
# 100
# 111
# 123
# 9
# 99
# 999
# 0
# 1
# 2

# %%
for i in range(len(list2D)):
    for j in range(len(list2D[i])):
        print(list2D[i][j], end=" ")
    print()
# Out:
# 10 11 12 13
# 100 111 123 156
# 9 99 999 9999
# 0 1 2
