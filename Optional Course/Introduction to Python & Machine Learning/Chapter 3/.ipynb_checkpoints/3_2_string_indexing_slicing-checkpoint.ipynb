# %%
prompt = "What is your name?"

prompt
# Out:
# 'What is your name?'

# %%
print(type(prompt))
# Out:
# <class 'str'>

# %%
message = """ tell me about your self?
What are the isssues you've been facing while learing the code"""

# %%
message
# Out:
# " tell me about your self?\nWhat are the isssues you've been facing while learing the code"

# %%
str = "Hello World!"

str
# Out:
# 'Hello World!'

# %%
for a in range(len(str)):
    print(str[a]," ")
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d
# !

# %% [markdown]
# ### Indexing and Slicing

# %%
str[0]
# Out:
# 'H'

# %%
firstMessage = message[0:25]

firstMessage
# Out:
# ' tell me about your self?'

# %%
firstMessage = message[0:25:1]

firstMessage
# Out:
# ' tell me about your self?'

# %%
firstMessage = message[0:25:2]

firstMessage
# Out:
# ' elm bu orsl?'

# %%
print(firstMessage)
# Out:
#  elm bu orsl?

# %%
firstMessage[-1]
# Out:
# '?'

# %%
firstMessage = firstMessage[::-1]

firstMessage
# Out:
# '?lsro ub mle '
