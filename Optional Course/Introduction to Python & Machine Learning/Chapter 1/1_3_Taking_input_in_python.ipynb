# %%
name = input("Enter your name: ")

print(name)
# Out:
# Shaon Khan

# %%
age = input("Enter your age: ")
print(f"Your age is: {age}",type(age),"It's string")
# Out:
# Your age is: 22 <class 'str'> It's string

# %%
age = input("Enter age: ")  #Method 1
age = int(age)
print(type(age))
# Out:
# <class 'int'>

# %%
age = int(input("Enter your age: "))  #Method 2
print(f"Your age is: {age}")
# Out:
# Your age is: 22

# %%
height = float(input("Enter height: "))  #String to float type casting...
print(height,f"  Height data type is:{type(height)}")
# Out:
# 5.6   Height data type is:<class 'float'>

# %%
height += 0.2
print(height)
# Out:
# 5.8

# %%
height += 3
print(type(height))
# Out:
# <class 'float'>
