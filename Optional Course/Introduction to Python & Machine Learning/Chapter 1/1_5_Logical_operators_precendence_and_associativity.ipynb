# %% [markdown]
# Logical Operators

# %% [markdown]
# and or

# %%
x = 10
y = 5
z = 3

# %%
result = (x > y) and (x > z)

# %%
result
# Out:
# True

# %%
result2 = (x > y) and (x < y)

# %%
result2
# Out:
# False

# %%
result3 = (x > y) or (x < y)

# %%
result3
# Out:
# True

# %%
result4 = (y > x) or (z > y)

# %%
result4
# Out:
# False

# %% [markdown]
# Precendence and Associativity

# %%
eq = 10 + 10/2 - 5*2
eq
# Out:
# 5.0

# %%
eq2 = (10+10)/2 - 5*2
eq2
# Out:
# 0.0
