# %%
first, second = map(int,input().split())
#first, second = arr[0], arr[1]

first_last_digit,second_last_digit = first % 10, second % 10

answer = first_last_digit + second_last_digit

print(answer)
# Out:
# 5

# %%
first2 = int(input())
second2 = int(input())

first_last_digit2,second_last_digit2 = first2 % 10, second2 % 10

answer2 = first_last_digit2 + second_last_digit2

answer2
# Out:
# 3
