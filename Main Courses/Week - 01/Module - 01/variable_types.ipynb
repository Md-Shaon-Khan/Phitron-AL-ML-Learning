# %%
a = 10

print(a,type(a))
# Out:
# 10 <class 'int'>

# %%
b = 10.5

print(b,type(b))
# Out:
# 10.5 <class 'float'>

# %%
print(a,b,'\n',type(a),type(b))

a, b = b, a

print(a,b,'\n',type(a),type(b))
# Out:
# 10 10.5
#  <class 'int'> <class 'float'>
# 10.5 10
#  <class 'float'> <class 'int'>

# %%
c = '10'

print(c,type(c))
# Out:
# 10 <class 'str'>

# %%
name = "shaon Khan"

print(name,type(name))
print(name[0],name[1])
# Out:
# shaon Khan <class 'str'>
# s h

# %%
name1 = input()

print(name1,type(name1))
# Out:
# Shaon Khan <class 'str'>

# %%
a = input()

print(a,type(a))
# Out:
# 10 <class 'str'>

# %%
b = input()

b = int(b)

print(b,type(b))
# Out:
# 10 <class 'int'>

# %%
trying_error = input()

trying_error = int(trying_error)

print(trying_error,type(trying_error))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 trying_error = input()
# ----> 3 trying_error = int(trying_error)
#       5 print(trying_error,type(trying_error))
#
# ValueError: invalid literal for int() with base 10: '10 20 30'

# %%
error_fixed = input()

print(error_fixed,type(error_fixed))
# Out:
# 10 20 30 <class 'str'>

# %%
strNumber = input()

print(strNumber,type(strNumber))

intNumber = strNumber.split()

print(intNumber,type(intNumber))
# Out:
# 10 20 30 <class 'str'>
# ['10', '20', '30'] <class 'list'>

# %%
index_1_intNumber = intNumber[0]

print(index_1_intNumber,type(index_1_intNumber))

index_1_int = int(index_1_intNumber)

print(index_1_int,type(index_1_int))
# Out:
# 10 <class 'str'>
# 10 <class 'int'>

# %%
index_2_intNumber = intNumber[1]

print(index_2_intNumber,type(index_2_intNumber))

index_2_int = int(index_2_intNumber)

print(index_2_int,type(index_2_int))
# Out:
# 20 <class 'str'>
# 20 <class 'int'>

# %%
index_1_int + index_2_int
# Out:
# 30

# %%
intNumber,type(intNumber),(intNumber[0])
# Out:
# (['10', '20', '30'], list, '10')

# %%
direct_int_input = list(map(int,input().split()))

print(direct_int_input,type(direct_int_input),direct_int_input[0],type(direct_int_input[0]))
# Out:
# [10, 20, 30] <class 'list'> 10 <class 'int'>

# %% [markdown]
# Wrong

# %%
direct_int_input = list((int,input().split()))

print(direct_int_input,type(direct_int_input),direct_int_input[0],type(direct_int_input[0]))
# Out:
# [<class 'int'>, ['102', '20', '30']] <class 'list'> <class 'int'> <class 'type'>

# %% [markdown]
# Wrong

# %%
direct_int_input = list((input().split(),int))

print(direct_int_input,type(direct_int_input),direct_int_input[0],type(direct_int_input[0]))
# Out:
# [['10', '20', '30'], <class 'int'>] <class 'list'> ['10', '20', '30'] <class 'list'>

# %% [markdown]
# Right

# %%
direct_int_input = list(map(int,input().split()))

print(direct_int_input,type(direct_int_input),direct_int_input[0],type(direct_int_input[0]))
# Out:
# [10, 20, 304, 0] <class 'list'> 10 <class 'int'>
