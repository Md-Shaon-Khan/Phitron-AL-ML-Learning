# %%
import random

# %%
a = random.random()
# we can use also
# a = round(random.uniform(0,1),2)
if round(a,2) == 0.80:
  print("We can't classify, let's do again.")
elif round(a,2) > 0.80:
  print("Hurreh Shaon Becomes an AI/ML Expert")
else:
  print("Never Give Up")
# Out:
# Hurreh Shaon Becomes an AI/ML Expert
