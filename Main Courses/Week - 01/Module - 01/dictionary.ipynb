# %%
import pandas as pd

ml_results = {
  'Model':['KNN','Random Forest','Logistic Regression'],
  'Besk K':[5,100,None],
  'Accuracy':[22.22,33.55,66.66],
  'Train Time Sec':[0.1,0.3,4]
}

df = pd.DataFrame(ml_results)
df
# Out:
#                  Model  Besk K  Accuracy  Train Time Sec
# 0                  KNN     5.0     22.22             0.1
# 1        Random Forest   100.0     33.55             0.3
# 2  Logistic Regression     NaN     66.66             4.0

# %%
print(ml_results['Model'])
# Out:
# ['KNN', 'Random Forest', 'Logistic Regression']

# %%
df[['Model']]
# Out:
#                  Model
# 0                  KNN
# 1        Random Forest
# 2  Logistic Regression

# %%
df[['Model','Accuracy']]
# Out:
#                  Model  Accuracy
# 0                  KNN     22.22
# 1        Random Forest     33.55
# 2  Logistic Regression     66.66

# %%
ml_results.keys()
# Out:
# dict_keys(['Model', 'Besk K', 'Accuracy', 'Train Time Sec'])

# %%
ml_results.values()
# Out:
# dict_values([['KNN', 'Random Forest', 'Logistic Regression'], [5, 100, None], [22.22, 33.55, 66.66], [0.1, 0.3, 4]])

# %%
ml_results
# Out:
# {'Model': ['KNN', 'Random Forest', 'Logistic Regression'],
#  'Besk K': [5, 100, None],
#  'Accuracy': [22.22, 33.55, 66.66],
#  'Train Time Sec': [0.1, 0.3, 4]}
