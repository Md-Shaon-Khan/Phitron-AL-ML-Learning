# %%
import random
import statistics

# %%
range_Of_random = range(1,51)

list1 = []
for i in range_Of_random:
  number = random.random()
  list1.append(number)
  
print(list1)
print(max(list1))
print(max(list1), list1.index(max(list1)))
print(statistics.mean(list1))
print(sum(list1) / len(list1))
# Out:
# [0.9144708617433485, 0.10327760528563013, 0.2977637571211982, 0.9858856218046587, 0.23492289371922792, 0.5401866678047738, 0.06567501587264324, 0.16548232985710576, 0.9977336870279211, 0.4238067445054028, 0.8335331798882106, 0.8455938440031244, 0.20715585714709484, 0.71800573263095, 0.4283376450758024, 0.16026767142511866, 0.0831833922555355, 0.09788686290169868, 0.05180943880335964, 0.2516998921675494, 0.49779423536397416, 0.3732934265250175, 0.9420540282744777, 0.5099680988568316, 0.22865896196465763, 0.8909507624595941, 0.04028443373959012, 0.3442341362039716, 0.035536866130364886, 0.43916387580856864, 0.7553940304798519, 0.38309591956513167, 0.6417593496200609, 0.18994184883622567, 0.11618199238514959, 0.18517681239023165, 0.9590228923680811, 0.9226794394737254, 0.8815623569977026, 0.7635475300827004, 0.03530457656335617, 0.4105740610462496, 0.6278813226924977, 0.983568636989689, 0.8301953565165855, 0.2397463959413929, 0.505159458333451, 0.5616300080233361, 0.8781717178055477, 0.
# ...
