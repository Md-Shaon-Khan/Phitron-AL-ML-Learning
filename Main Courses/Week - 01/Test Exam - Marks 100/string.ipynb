# %%
mm = "What is your name?"
print(mm,type(mm))
# Out:
# What is your name? <class 'str'>

# %%
pythonmsg = """
Tell me about your self?
Who are you?
Where you from?"""

print(pythonmsg)
# Out:
# Tell me about your self?
# Who are you?
# Where you from?

# %%
help(pythonmsg)
# Out:
# No Python documentation found for 'Tell me about your self?\nWho are you?\nWhere you from?'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.

# %%
msg = "Shaon Khan"

print(msg[::-1])
# Out:
# nahK noahS

# %%
check = "Shaon" in msg
print(check)
# Out:
# True

# %%
msg = msg + " added one more Shaon"

start = msg.find("Shaon")
print(start,msg)
print(msg)
# Out:
# 0 Shaon Khan added one more Shaon
# Shaon Khan added one more Shaon

# %%
last = msg.rfind("Shaon")
print(last)
# Out:
# 26

# %%
print(msg)
msgList = msg.split()
print(msgList)
# Out:
# Shaon Khan added one more Shaon
# ['Shaon', 'Khan', 'added', 'one', 'more', 'Shaon']

# %%
msg = "--".join(msgList)
print(msg)
# Out:
# Shaon--Khan--added--one--more--Shaon

# %%
name = "Adil"
age = 23
height = .1123445

info = f"His name is {name.upper()}. He is {age} years old. He is {height:.3} feet tall.\\n"
print(info)
# Out:
# His name is ADIL. He is 23 years old. He is 0.112 feet tall.\n

# %%
random_list = [x for x in range(1,11) if x % 2 == 0]
print(random_list)
# Out:
# [2, 4, 6, 8, 10]

# %%
fruits = ['ApPle','Orange','LichI']

fruits2 = [x.lower() for x in fruits]
print(fruits2)
# Out:
# ['apple', 'orange', 'lichi']

# %%
t = (1,2,3,4)

print(t)
print(type(t))
# Out:
# (1, 2, 3, 4)
# <class 'tuple'>

# %%
t1 = (6,)
print(t1,type(t1))
# Out:
# (6,) <class 'tuple'>

# %%
t1 = (1, 2)
t2 = (3, 4)

print(t1 + t2)
print(t1 * 2)
print(t1)
# Out:
# (1, 2, 3, 4)
# (1, 2, 1, 2)
# (1, 2)

# %%
set1 = set()
set2 = {}
print(type(set1),set1)
# Out:
# <class 'set'> set()

# %%
person = {
  'name':'Shaon Khan',
  'age': 22,
  'subject':'ICT'
}

print(person['name'])
print(person.get('name'))
# Out:
# Shaon Khan
# Shaon Khan

# %%
person['cgpa'] = 3.78
print(person)
# Out:
# {'name': 'Shaon Khan', 'age': 22, 'subject': 'ICT', 'cgpa': 3.78}

# %%
person.pop('age')
print(person)
# Out:
# {'name': 'Shaon Khan', 'subject': 'ICT', 'cgpa': 3.78}

# %%
students = {
"101": {"name": "Rafi", "grade": "A"},
"102": {"name": "Mina", "grade": "B"}
}
print(students)
# Out:
# {'101': {'name': 'Rafi', 'grade': 'A'}, '102': {'name': 'Mina', 'grade': 'B'}}

# %%
keys = ['name','age','roll']
defaults = dict.fromkeys(keys,[['Shaon'],22,1984])
print(defaults)
# Out:
# {'name': [['Shaon'], 22, 1984], 'age': [['Shaon'], 22, 1984], 'roll': [['Shaon'], 22, 1984]}

# %%
keys = ['name','age','roll']
values = ['Shaon',22,1984]

defaults = dict(zip(keys,values))
print(defaults)
# Out:
# {'name': 'Shaon', 'age': 22, 'roll': 1984}
