# %%
dictionary = {}

for i in range(1,6):
  name, marks = input().split()
  
  dictionary[name] = int(marks)

sorted_dict = dict(sorted(dictionary.items(),key=lambda item:item[1], reverse=True))

top_name, top_marks = next(iter(sorted_dict.items()))
print(dictionary)
print(top_marks)
# Out:
# {'Shaon': 12, 'Raunaq': 13, 'Ayan': 89, 'Shahadat': 90, 'Nayem': 1}
# 90
