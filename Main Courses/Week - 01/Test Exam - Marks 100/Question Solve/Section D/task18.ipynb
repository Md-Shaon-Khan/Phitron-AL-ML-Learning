# %%
numbers1 = list(map(int,input().split()))
numbers2 = list(map(int,input().split()))


numbers1 = set(numbers1)
numbers2 = set(numbers2)

common = numbers1 & numbers2
difference = numbers1 - numbers2
allNum = numbers1 | numbers2

print(common)
print(difference)
print(allNum)
# Out:
# {4, 5}
# {1, 2, 3}
# {1, 2, 3, 4, 5, 6, 7, 8}
