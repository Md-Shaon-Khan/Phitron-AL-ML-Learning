# %%
dictionary = {}

string = input().split(' ')

for i in range(len(string)):
  name = string[i]
  dictionary[name] = string.count(string[i])
  
print(dictionary)
# Out:
# {'the': 2, 'cat': 1, 'sat': 1, 'on': 1, 'mat': 1}
