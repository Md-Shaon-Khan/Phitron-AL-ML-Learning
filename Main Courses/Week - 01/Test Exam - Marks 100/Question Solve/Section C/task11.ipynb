# %%
string = input()

len_str = len(string)
print(len_str)

lower_str = string.lower()

vowels = lower_str.count('a') + lower_str.count('e') + lower_str.count('i') + lower_str.count('o') + lower_str.count('u') 
print(vowels)

print(string[::-1])
print(string.upper())
# Out:
# 5
# 2
# elppa
# APPLE
