# %%
numbers = list(map(int,input().split()))


even_numbers = [x for x in numbers if x%2==0]

print(even_numbers)

squares_of_odd = [x**2 for x in numbers if x%2==1]

print(squares_of_odd)
# Out:
# [2, 4, 6]
# [1, 9, 25, 49]
