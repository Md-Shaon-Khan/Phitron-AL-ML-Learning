# %%
f = open('data.txt','w')
f.write('Hello python!')
f.close()

# %%
f2 = open('data.txt','r')
print(f2.read())
f2.close()
# Out:
# Hello python!

# %%
d3 = open('data.txt','w')
d3.write('New overwrite')

d3.close()

# %%
with open('data.txt','w') as f:
  f.write('Using with function we write.')

# %%
with open('data.txt','a') as f:
  f.write('\nA new line added here using append')

# %%
with open('data.txt','r',encoding='utf-8') as f:
  data = f.read()

print(data)
# Out:
# Using with function we write.
# A new line added here using append

# %%
with open('data.txt','r',encoding='utf-8') as f:
  for line in f:
    print(line.strip())
# Out:
# Using with function we write.
# A new line added here using append

# %%
try:
  with open('story.txt','r',encoding='utf-8') as f:
    print(f.read())
except FileNotFoundError:
  print('No such file founded.')
# Out:
# No such file founded.

# %%
from pathlib import Path

p = Path('Practice2', 'data.txt')

p.parent.mkdir(parents=True,exist_ok=True)
with p.open('a',encoding='utf-8') as f:
  f.write('using Pathlib a line added...')

# %%
with open('data.txt','w',encoding='utf-8') as f:
  f.write('Hello Bangladesh!')

# %%
with open('data.txt','r',encoding='utf-8') as f:
  data = f.read()

print(data)
# Out:
# Hello Bangladesh!

# %%
with open('data.txt','a',encoding='utf-8') as f:
  f.write('\nPython Rocks, Shaon Shocks!')

# %%
from pathlib import Path

p = Path('data.txt')
text = p.read_text(encoding='utf-8')

text = text.replace('Hello Bangladesh!','Hello Bangladesh!\n')

p.write_text(text,encoding='utf-8')
# Out:
# 73

# %%
f = open('data.txt','r',encoding='utf-8')
data = f.read()
print(data)

f.close()
# Out:
# Hello Bangladesh!
# Python Rocks, Shaon Shocks!
# Python Rocks, Shaon Shocks!

# %%
with open('data.txt','r',encoding='utf-8') as f:
  text = f.read()
print(text)
# Out:
# Hello Bangladesh!
# Python Rocks, Shaon Shocks!
# Python Rocks, Shaon Shocks!

# %%
with open('data.txt','r',encoding='utf-8') as f:
  line1 = f.readline()
  line2 = f.readline()

print(line1)
print(line2)
# Out:
# Hello Bangladesh!
#
# Python Rocks, Shaon Shocks!

# %%
with open('data.txt','r',encoding='utf-8') as f:
  lines = f.readlines()
print(lines)
# Out:
# ['Hello Bangladesh!\n', 'Python Rocks, Shaon Shocks!\n', 'Python Rocks, Shaon Shocks!']

# %%
with open('data.txt','r',encoding='utf-8') as f:
  # for line in f.readline():
  #   print(line.strip())
  for line in f:
    print(line.strip())
# Out:
# Hello Bangladesh!
# Python Rocks, Shaon Shocks!
# Python Rocks, Shaon Shocks!

# %%
f = open('data.txt','r',encoding='utf-8')
print(f.read(5))
print(f.read())
f.seek(0)
print(f.read(10))
f.close()
# Out:
# Hello
#  Bangladesh!
# Python Rocks, Shaon Shocks!
# Python Rocks, Shaon Shocks!
# Hello Bang

# %%
with open('data.txt','r') as f:
  part = f.read(20)
print(part)
# Out:
# Hello Bangladesh!
# Py

# %%
f = open('data.txt','r',encoding='utf-8')
content = f.read(5)
print(content)

position = f.tell()
print(position)
f.close()
# Out:
# Hello
# 5

# %%
with open('data.txt','r',encoding='utf-8') as f:
  print(f.read(8))
  f.seek(0)
  print(f.read(6))
# Out:
# Hello Ba
# Hello

# %%
a = open('sample.txt', 'w', encoding='utf-8')
a.write('ABC')
print(a.tell())

a.close()


b = open('sample.txt', 'a', encoding='utf-8')
print(b.tell())
b.write('\nDEF')
b.close()
# Out:
# 3
# 3

# %%
with open('data.txt', 'r', encoding='utf-8') as f:
 for i, line in enumerate(f, start=1):
  print(f'{i}: {line.strip()}')
# Out:
# 1: Hello Bangladesh!
# 2: Python Rocks, Shaon Shocks!
# 3: Python Rocks, Shaon Shocks!
