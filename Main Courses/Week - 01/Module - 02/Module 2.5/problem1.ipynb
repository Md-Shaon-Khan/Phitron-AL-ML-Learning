# %%
def introduce(name, age):
  print(f"My name is {name} and I am {age} years old.")
  
name, age = map(str,input().split())
age =  int(age)
introduce(name, age)
# Out:
# My name is Shaon and I am 22 years old.

# %%
def introduce(name, age):
  print(f"My name is {name} and I am {age} years old.")
  
name, age = input().rsplit(" ",1)
introduce(name, age)
# Out:
# My name is Shaon and I am Khan years old.
