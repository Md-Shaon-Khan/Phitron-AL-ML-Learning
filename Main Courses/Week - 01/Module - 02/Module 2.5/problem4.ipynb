# %%
lst = [1,2,3,4,5,6]

print(list(x**2 for x in list(filter(lambda x: x%2 == 0 ,lst))))
# Out:
# [4, 16, 36]

# %%
lst1 = [1,2,3,4,5,6]

print(list(map(lambda x:x**2,filter(lambda x:x%2==0,lst1))))
# Out:
# [4, 16, 36]
