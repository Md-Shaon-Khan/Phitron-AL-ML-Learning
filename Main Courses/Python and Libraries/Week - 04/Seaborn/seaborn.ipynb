# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('sns_data.csv')
df.head()
# Out:
#    student_id class_level   subject  study_hours  test_score  week  \
# 0           1    Freshman      Math            5          78     1
# 1           2    Freshman   Science            3          65     1
# 2           3    Freshman   History            4          70     1
# 3           4    Freshman  Language            2          60     1
# 4           5   Sophomore      Math            6          82     1
#
#    attendance_rate  gender  hostel  Tshirt_size
# 0               90    Male    True           30
# 1               80  Female   False           20
# 2               85    Male    True           20
# 3               75  Female    True           40
# 4               92    Male    True           20

# %%
sns.lineplot(data = df,x = 'week', y= 'attendance_rate')
# Out:
# <Axes: xlabel='week', ylabel='attendance_rate'>

# %%
sns.lineplot( data = df, x = 'week', y = 'attendance_rate', errorbar = None, hue = 'gender')
# Out:
# <Axes: xlabel='week', ylabel='attendance_rate'>

# %%
sns.relplot(kind = 'line', data = df, x = 'week', y = 'attendance_rate', errorbar = None, hue = 'gender')

# %%
sns.lineplot( data = df, x = 'week', y = 'test_score', errorbar = None, hue = 'gender')
# Out:
# <Axes: xlabel='week', ylabel='test_score'>

# %%
sns.relplot(kind = 'line', data = df, x = 'week', y = 'attendance_rate', errorbar = None, hue = 'class_level')

# %%
sns.scatterplot(data = df, x = 'study_hours', y = 'test_score')
# Out:
# <Axes: xlabel='study_hours', ylabel='test_score'>

# %%
sns.scatterplot(data = df, x = 'study_hours', y = 'test_score', hue = 'gender', style = 'class_level')
# Out:
# <Axes: xlabel='study_hours', ylabel='test_score'>

# %%
student = pd.read_csv('student_dataset_complete.csv')
student.head()
# Out:
#    number_courses  time_study   Marks  student_id  class_level  subject  \
# 0               3       4.508  19.202           1           10  Science
# 1               4       0.096   7.734           2           12     Math
# 2               4       3.133  13.811           3           11  Science
# 3               6       7.909  53.018           4           10  Science
# 4               8       7.811  55.299           5           11  English
#
#    study_hours  test_score  week  attendance_rate gender  hostel  Tshirt_size  \
# 0        4.508      19.202     2             0.89      F       0            2
# 1        0.096       7.734     3             0.98      M       0            3
# 2        3.133      13.811     5             0.83      F       0            3
# 3        7.909      53.018     4             0.92      F       1            4
# 4        7.811      55.299     3             0.80      M       1            4
#
#   class_name
# 0  Sophomore
# 1     Senior
# 2     Junior
# ...

# %%
sns.scatterplot(data = student, x = 'study_hours', y = 'test_score', hue = 'gender')
# Out:
# <Axes: xlabel='study_hours', ylabel='test_score'>

# %%
sns.relplot(kind = 'scatter', data = student, x = 'study_hours', y = 'test_score', hue = 'gender')

# %%
sns.relplot(kind = 'scatter', data = student, x = 'study_hours', y = 'test_score', hue = 'gender', col = 'gender')

# %%
sns.relplot(kind = 'scatter', data = student, x = 'study_hours', y = 'test_score', hue = 'gender', col = 'class_level')

# %%
sns.relplot(kind = 'scatter', data = student, x = 'study_hours', y = 'test_score', col = 'gender', row = 'hostel')

# %%
sns.relplot(kind = 'scatter', data = student, x = 'study_hours', y = 'test_score', col = 'week', row = 'hostel')

# %%
sns.relplot(kind = 'scatter', data = student, x = 'study_hours', y = 'test_score', col = 'week', col_wrap = 3)

# %% [markdown]
# ## Histogram

# %%
sns.histplot(data = student, x = 'attendance_rate')
# Out:
# <Axes: xlabel='attendance_rate', ylabel='Count'>

# %%
sns.histplot(data = student, x = 'attendance_rate', bins = 10)
# Out:
# <Axes: xlabel='attendance_rate', ylabel='Count'>

# %%
sns.histplot(data = student, x = 'attendance_rate', hue = 'gender')
# Out:
# <Axes: xlabel='attendance_rate', ylabel='Count'>

# %%
sns.histplot(data = student, x = 'attendance_rate', hue = 'gender', element = 'step')
# Out:
# <Axes: xlabel='attendance_rate', ylabel='Count'>

# %%
sns.displot(kind = 'hist', data =  student, x = 'attendance_rate')

# %%
sns.displot(kind = 'hist', data =  student, x = 'attendance_rate', col = 'gender')

# %%
sns.displot(kind = 'hist', data =  student, x = 'study_hours', col = 'gender')

# %% [markdown]
# # KDE

# %%
tips_data = sns.load_dataset('tips')
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(kind  = 'hist', data = tips_data, x = 'total_bill')

# %%
sns.displot(kind  = 'hist', data = tips_data, x = 'total_bill', bins  =20)

# %%
sns.displot(kind  = 'hist', data = tips_data, x = 'tip')

# %%
sns.kdeplot(data = student, x = 'attendance_rate')
# Out:
# <Axes: xlabel='attendance_rate', ylabel='Density'>

# %%
sns.kdeplot(data = tips_data, x = 'tip')
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.kdeplot(data = tips_data, x = 'tip', hue = 'sex')
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.kdeplot(data = tips_data, x = 'tip', hue = 'sex', fill = True)
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %% [markdown]
# # Count Plot & Bar Plot

# %%
student
# Out:
#     number_courses  time_study   Marks  student_id  class_level  subject  \
# 0                3       4.508  19.202           1           10  Science
# 1                4       0.096   7.734           2           12     Math
# 2                4       3.133  13.811           3           11  Science
# 3                6       7.909  53.018           4           10  Science
# 4                8       7.811  55.299           5           11  English
# ..             ...         ...     ...         ...          ...      ...
# 95               6       3.561  19.128          96           11  English
# 96               3       0.301   5.609          97           10  Science
# 97               4       7.163  41.444          98           11     Math
# 98               7       0.309  12.027          99           12     Math
# 99               3       6.335  32.357         100           12  Science
#
#     study_hours  test_score  week  attendance_rate gender  hostel  \
# ...

# %%
sns.countplot(data = student, x = 'gender')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(data = student, x='subject', hue='gender')
# Out:
# <Axes: xlabel='subject', ylabel='count'>

# %%
sns.barplot(data=student, x = 'subject', y = 'test_score')
# Out:
# <Axes: xlabel='subject', ylabel='test_score'>

# %%
sns.barplot(data = student, x='gender', y='Marks', errorbar=None)
# Out:
# <Axes: xlabel='gender', ylabel='Marks'>

# %%
sns.barplot(data = student, x = 'gender', y = 'Marks', errorbar=None, estimator=np.median)
# Out:
# <Axes: xlabel='gender', ylabel='Marks'>

# %% [markdown]
# # Reg Plot

# %%
sns.regplot(data = student, x = 'study_hours', y = 'test_score')
# Out:
# <Axes: xlabel='study_hours', ylabel='test_score'>

# %%
sns.lmplot(data = student, x = 'study_hours', y = 'test_score', col = 'gender')

# %% [markdown]
# # Pairplot and Joint Plot

# %%
student_marks = student[['Marks','study_hours','attendance_rate','gender']]
student_marks.head()
# Out:
#     Marks  study_hours  attendance_rate gender
# 0  19.202        4.508             0.89      F
# 1   7.734        0.096             0.98      M
# 2  13.811        3.133             0.83      F
# 3  53.018        7.909             0.92      F
# 4  55.299        7.811             0.80      M

# %%
sns.pairplot(data = student_marks)

# %%
sns.pairplot(data = student_marks, hue = 'gender')

# %%
sns.pairplot(data = student_marks, kind = 'hist')

# %%
sns.jointplot(data = student, x = 'study_hours', y = 'test_score', kind = 'kde')
