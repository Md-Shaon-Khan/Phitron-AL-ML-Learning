# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Practice.csv')
df
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank   NaN  75000.0   2200      90      91      92
# 7        E107        Grace  34.0      NaN   1900      81      83      80
# 8        E108        Heidi  38.0      NaN   1800      84      86      88
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0  60000.0   1500      78      82      80

# %%
df_copy = df.copy()
df_copy
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank   NaN  75000.0   2200      90      91      92
# 7        E107        Grace  34.0      NaN   1900      81      83      80
# 8        E108        Heidi  38.0      NaN   1800      84      86      88
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0  60000.0   1500      78      82      80

# %%
df_copy['Discounted_Price'] = df_copy['Salary']*.90
df_copy
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank   NaN  75000.0   2200      90      91      92
# 7        E107        Grace  34.0      NaN   1900      81      83      80
# 8        E108        Heidi  38.0      NaN   1800      84      86      88
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0  60000.0   1500      78      82      80
#
#     Discounted_Price
# 0            45000.0
# 1            54000.0
# 2            46800.0
# ...

# %%
df_copy.to_csv('Discounted_Products.csv',index=False)

# %%
df
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank   NaN  75000.0   2200      90      91      92
# 7        E107        Grace  34.0      NaN   1900      81      83      80
# 8        E108        Heidi  38.0      NaN   1800      84      86      88
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0  60000.0   1500      78      82      80

# %%
df_copy['EmployeeID'].duplicated().sum()
# Out:
# np.int64(2)

# %%
df_copy_2 = df_copy.drop_duplicates(subset=['EmployeeID'])
df_copy_2
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E102          Bob  30.0  60000.0   1500      78      82      80
# 2       E103      Charlie  22.0  52000.0   1100      92      95      90
# 4       E104        David  45.0  80000.0   2500      88      85      89
# 5       E105          Eve  29.0  58000.0   1300      76      79      81
# 6       E106        Frank   NaN  75000.0   2200      90      91      92
# 7       E107        Grace  34.0      NaN   1900      81      83      80
# 8       E108        Heidi  38.0      NaN   1800      84      86      88
# 9       E109         Ivan  26.0  53000.0   1400      95      92      94
#
#    Discounted_Price
# 0           45000.0
# 1           54000.0
# 2           46800.0
# 4           72000.0
# 5           52200.0
# 6           67500.0
# 7               NaN
# 8               NaN
# 9           47700.0

# %%
df_copy
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank   NaN  75000.0   2200      90      91      92
# 7        E107        Grace  34.0      NaN   1900      81      83      80
# 8        E108        Heidi  38.0      NaN   1800      84      86      88
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0  60000.0   1500      78      82      80
#
#     Discounted_Price
# 0            45000.0
# 1            54000.0
# 2            46800.0
# ...

# %%
df_copy[['Age','Salary']].isnull().sum()
df_copy_3 = df_copy.copy()
df_copy_3['Age'] = df_copy['Age'].fillna(df_copy['Age'].mean())
df_copy_3
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank  30.4  75000.0   2200      90      91      92
# 7        E107        Grace  34.0      NaN   1900      81      83      80
# 8        E108        Heidi  38.0      NaN   1800      84      86      88
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0  60000.0   1500      78      82      80
#
#     Discounted_Price
# 0            45000.0
# 1            54000.0
# 2            46800.0
# ...

# %%
df_copy['Age'].mean()
# Out:
# np.float64(30.4)

# %%
df_copy_3 = df_copy_3.dropna(subset=['Salary'])

# %%
df_copy_3
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank  30.4  75000.0   2200      90      91      92
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0  60000.0   1500      78      82      80
#
#     Discounted_Price
# 0            45000.0
# 1            54000.0
# 2            46800.0
# 3            45000.0
# 4            72000.0
# 5            52200.0
# 6            67500.0
# 9            47700.0
# 10           54000.0

# %%
print(df['Marks1'].mean())
print(df['Marks1'].max())

print(df['Marks2'].mean())
print(df['Marks2'].max())

print(df['Marks3'].mean())
print(df['Marks3'].max())
# Out:
# 84.72727272727273
# 95
# 86.81818181818181
# 95
# 86.36363636363636
# 94

# %%
df.describe()
# Out:
#              Age        Salary        Price     Marks1     Marks2     Marks3
# count  10.000000      9.000000    11.000000  11.000000  11.000000  11.000000
# mean   30.400000  59777.777778  1600.000000  84.727273  86.818182  86.363636
# std     6.947422  10848.707040   449.444101   6.149649   5.075789   5.182137
# min    22.000000  50000.000000  1100.000000  76.000000  79.000000  80.000000
# 25%    25.250000  52000.000000  1250.000000  79.500000  82.500000  80.500000
# 50%    29.500000  58000.000000  1500.000000  85.000000  86.000000  88.000000
# 75%    33.000000  60000.000000  1850.000000  89.000000  90.500000  89.500000
# max    45.000000  80000.000000  2500.000000  95.000000  95.000000  94.000000

# %%
df_copy_4 = df_copy.copy()

df_copy_4['Total Marks'] = df_copy_4['Marks1'] + df_copy_4['Marks2'] + df_copy_4['Marks3']
df_copy_4
# Out:
#    EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0        E101        Alice  25.0  50000.0   1200      85      90      88
# 1        E102          Bob  30.0  60000.0   1500      78      82      80
# 2        E103      Charlie  22.0  52000.0   1100      92      95      90
# 3        E101        Alice  25.0  50000.0   1200      85      90      88
# 4        E104        David  45.0  80000.0   2500      88      85      89
# 5        E105          Eve  29.0  58000.0   1300      76      79      81
# 6        E106        Frank   NaN  75000.0   2200      90      91      92
# 7        E107        Grace  34.0      NaN   1900      81      83      80
# 8        E108        Heidi  38.0      NaN   1800      84      86      88
# 9        E109         Ivan  26.0  53000.0   1400      95      92      94
# 10       E102          Bob  30.0  60000.0   1500      78      82      80
#
#     Discounted_Price  Total Marks
# 0            45000.0          263
# ...

# %%
df_copy_4['Total Marks'].std()
# Out:
# 15.8395362650208

# %%
df_copy_4['Age'].min()
# Out:
# 22.0

# %%
df_copy_4['Age'].max()
# Out:
# 45.0

# %%
plt.hist(df['Age'])
# Out:
# (array([1., 3., 0., 3., 0., 1., 1., 0., 0., 1.]),
#  array([22. , 24.3, 26.6, 28.9, 31.2, 33.5, 35.8, 38.1, 40.4, 42.7, 45. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(df['Age'], df['Salary'])

# %%
plt.scatter(df_copy['Price'],df_copy['Discounted_Price'])
