# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('student_IQdata.csv')
df.head(2)
# Out:
#    Shoe_Size  Study_Hour  Chilling_Hours  IQ_Score
# 0       13.5         2.0            17.7        72
# 1        8.0        18.0             5.0        75

# %%
plt.scatter(df['Study_Hour'],df['IQ_Score'])

# %%
plt.scatter(df['Shoe_Size'],df['Study_Hour'])

# %%
plt.hist(df['Shoe_Size'])
# Out:
# (array([7., 8., 4., 5., 6., 3., 4., 0., 0., 1.]),
#  array([ 5.2 ,  6.48,  7.76,  9.04, 10.32, 11.6 , 12.88, 14.16, 15.44,
#         16.72, 18.  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.xlabel('Shoe Size')
plt.ylabel('Frequency')
plt.title('Shoe size with Frequency')

plt.legend()
plt.hist(df['Shoe_Size'])
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11748\4186959021.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df['Shoe_Size'].corr(df['IQ_Score'])
# Out:
# np.float64(0.13392528255987665)
