# %%
import pandas as pd

df = pd.read_csv('student_data.csv')

df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.loc[df['Mjob'].str.contains('home')]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1  at_home     other
# 2       GP   F   15       U     LE3       T     1     1  at_home     other
# 39      GP   F   15       R     GT3       T     2     2  at_home     other
# 79      GP   F   16       U     GT3       T     3     4  at_home     other
# 86      GP   F   16       U     LE3       T     2     2  at_home     other
# 95      GP   F   15       R     GT3       T     1     1  at_home     other
# 112     GP   F   16       U     GT3       T     2     2  at_home     other
# 120     GP   F   15       U     GT3       T     1     2  at_home  services
# 127     GP   F   19       U     GT3       T     0     1  at_home     other
# 131     GP   F   15       U     GT3       T     1     1  at_home     other
# ...

# %%
df.shape
# Out:
# (395, 33)

# %%
df.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.loc[df['Mjob'].str.contains('HOME', case=False)]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1  at_home     other
# 2       GP   F   15       U     LE3       T     1     1  at_home     other
# 39      GP   F   15       R     GT3       T     2     2  at_home     other
# 79      GP   F   16       U     GT3       T     3     4  at_home     other
# 86      GP   F   16       U     LE3       T     2     2  at_home     other
# 95      GP   F   15       R     GT3       T     1     1  at_home     other
# 112     GP   F   16       U     GT3       T     2     2  at_home     other
# 120     GP   F   15       U     GT3       T     1     2  at_home  services
# 127     GP   F   19       U     GT3       T     0     1  at_home     other
# 131     GP   F   15       U     GT3       T     1     1  at_home     other
# ...

# %%
df = pd.read_csv('students.csv')
df
# Out:
#    StudentID        FullName  Gender  Age Department  Semester  CGPA  \
# 0     PH1001     Alif Rahman    Male   19    Physics         1  3.75
# 1     PH1002   Fatima Akhter  Female   20    Physics         2  3.60
# 2     PH1003   Imran Hossain    Male   21    Physics         3  3.45
# 3     PH1004    Nusrat Jahan  Female   19    Physics         1  3.80
# 4     PH1005    Rafiul Islam    Male   22    Physics         4  3.30
# 5     PH1006   Sadia Sultana  Female   20    Physics         2  3.55
# 6     PH1007    Tanvir Ahmed    Male   21    Physics         3  3.20
# 7     PH1008     Umme Kulsum  Female   19    Physics         1  3.90
# 8     PH1009     Wahid Hasan    Male   22    Physics         4  3.10
# 9     PH1010    Yasmin Begum  Female   20    Physics         2  3.65
# 10    PH1011   Zahidul Karim    Male   21    Physics         3  3.40
# 11    PH1012    Anika Tasnim  Female   19    Physics         1  3.85
# 12    PH1013   Belal Hossain    Male   20    Physics         2  3.25
# ...

# %%
df.loc[df['FullName'].str.contains(r"^A")]
# Out:
#    StudentID      FullName  Gender  Age Department  Semester  CGPA Instructor  \
# 0     PH1001   Alif Rahman    Male   19    Physics         1  3.75  Mr. Karim
# 11    PH1012  Anika Tasnim  Female   19    Physics         1  3.85  Ms. Salma
#
#       Location
# 0        Dhaka
# 11  Chattogram

# %%
df.loc[df['FullName'].str.contains(r"^A", case=False)]
# Out:
#    StudentID      FullName  Gender  Age Department  Semester  CGPA Instructor  \
# 0     PH1001   Alif Rahman    Male   19    Physics         1  3.75  Mr. Karim
# 11    PH1012  Anika Tasnim  Female   19    Physics         1  3.85  Ms. Salma
#
#       Location
# 0        Dhaka
# 11  Chattogram

# %%
df.loc[df['FullName'].str.contains(r"im$")]
# Out:
#    StudentID       FullName  Gender  Age Department  Semester  CGPA  \
# 10    PH1011  Zahidul Karim    Male   21    Physics         3  3.40
# 11    PH1012   Anika Tasnim  Female   19    Physics         1  3.85
#
#    Instructor    Location
# 10  Mr. Karim       Dhaka
# 11  Ms. Salma  Chattogram

# %%
df.loc[df['FullName'].str.contains(r"^[AEIOU]")]
# Out:
#    StudentID       FullName  Gender  Age Department  Semester  CGPA  \
# 0     PH1001    Alif Rahman    Male   19    Physics         1  3.75
# 2     PH1003  Imran Hossain    Male   21    Physics         3  3.45
# 7     PH1008    Umme Kulsum  Female   19    Physics         1  3.90
# 11    PH1012   Anika Tasnim  Female   19    Physics         1  3.85
# 15    PH1016    Esrat Jahan  Female   19    Physics         1  3.70
#
#    Instructor    Location
# 0   Mr. Karim       Dhaka
# 2   Mr. Karim       Dhaka
# 7   Ms. Salma    Rajshahi
# 11  Ms. Salma  Chattogram
# 15  Ms. Salma  Chattogram

# %%
df.loc[df['FullName'].str.contains(r"u$")]
# Out:
# Empty DataFrame
# Columns: [StudentID, FullName, Gender, Age, Department, Semester, CGPA, Instructor, Location]
# Index: []

# %%
df.loc[df['FullName'].str.contains(r"^A|m$")]
# Out:
#    StudentID       FullName  Gender  Age Department  Semester  CGPA  \
# 0     PH1001    Alif Rahman    Male   19    Physics         1  3.75
# 4     PH1005   Rafiul Islam    Male   22    Physics         4  3.30
# 7     PH1008    Umme Kulsum  Female   19    Physics         1  3.90
# 9     PH1010   Yasmin Begum  Female   20    Physics         2  3.65
# 10    PH1011  Zahidul Karim    Male   21    Physics         3  3.40
# 11    PH1012   Anika Tasnim  Female   19    Physics         1  3.85
#
#    Instructor    Location
# 0   Mr. Karim       Dhaka
# 4   Mr. Karim       Dhaka
# 7   Ms. Salma    Rajshahi
# 9   Ms. Salma      Khulna
# 10  Mr. Karim       Dhaka
# 11  Ms. Salma  Chattogram
