# %%
import pandas as pd

df = pd.read_csv('students.csv')
df.head(2)
# Out:
#   StudentID       FullName  Gender  Age Department  Semester  CGPA Instructor  \
# 0    PH1001    Alif Rahman    Male   19    Physics         1  3.75  Mr. Karim
# 1    PH1002  Fatima Akhter  Female   20    Physics         2  3.60  Ms. Salma
#
#      Location
# 0       Dhaka
# 1  Chattogram

# %%
df['Country'] = 'Bangladesh'

# %%
df.head(2)
# Out:
#   StudentID       FullName  Gender  Age Department  Semester  CGPA Instructor  \
# 0    PH1001    Alif Rahman    Male   19    Physics         1  3.75  Mr. Karim
# 1    PH1002  Fatima Akhter  Female   20    Physics         2  3.60  Ms. Salma
#
#      Location     Country
# 0       Dhaka  Bangladesh
# 1  Chattogram  Bangladesh

# %%
df.Age.max()
# Out:
# np.int64(22)

# %%
df['New_CGPA'] = df['CGPA'] + (1 - (df['Age'] / 22))
df.head(3)
# Out:
#   StudentID       FullName  Gender  Age Department  Semester  CGPA Instructor  \
# 0    PH1001    Alif Rahman    Male   19    Physics         1  3.75  Mr. Karim
# 1    PH1002  Fatima Akhter  Female   20    Physics         2  3.60  Ms. Salma
# 2    PH1003  Imran Hossain    Male   21    Physics         3  3.45  Mr. Karim
#
#      Location     Country  New_CGPA
# 0       Dhaka  Bangladesh  3.886364
# 1  Chattogram  Bangladesh  3.690909
# 2       Dhaka  Bangladesh  3.495455

# %%
import numpy as np

# %%
df['New Subject'] = np.where(df['CGPA'] > 3.85 , 'A+','A-')
df.head()
# Out:
#   StudentID       FullName  Gender  Age Department  Semester  CGPA Instructor  \
# 0    PH1001    Alif Rahman    Male   19    Physics         1  3.75  Mr. Karim
# 1    PH1002  Fatima Akhter  Female   20    Physics         2  3.60  Ms. Salma
# 2    PH1003  Imran Hossain    Male   21    Physics         3  3.45  Mr. Karim
# 3    PH1004   Nusrat Jahan  Female   19    Physics         1  3.80  Ms. Salma
# 4    PH1005   Rafiul Islam    Male   22    Physics         4  3.30  Mr. Karim
#
#      Location     Country  New_CGPA New Subject
# 0       Dhaka  Bangladesh  3.886364          A-
# 1  Chattogram  Bangladesh  3.690909          A-
# 2       Dhaka  Bangladesh  3.495455          A-
# 3      Sylhet  Bangladesh  3.936364          A-
# 4       Dhaka  Bangladesh  3.300000          A-

# %%
# Data Structure Marks 70-এর বেশি হলে True, নাহলে False
df['Passed in DS'] = df['CGPA'] > 3.80

df.head(10)
# Out:
#   StudentID       FullName  Gender  Age Department  Semester  CGPA Instructor  \
# 0    PH1001    Alif Rahman    Male   19    Physics         1  3.75  Mr. Karim
# 1    PH1002  Fatima Akhter  Female   20    Physics         2  3.60  Ms. Salma
# 2    PH1003  Imran Hossain    Male   21    Physics         3  3.45  Mr. Karim
# 3    PH1004   Nusrat Jahan  Female   19    Physics         1  3.80  Ms. Salma
# 4    PH1005   Rafiul Islam    Male   22    Physics         4  3.30  Mr. Karim
# 5    PH1006  Sadia Sultana  Female   20    Physics         2  3.55  Ms. Salma
# 6    PH1007   Tanvir Ahmed    Male   21    Physics         3  3.20  Mr. Karim
# 7    PH1008    Umme Kulsum  Female   19    Physics         1  3.90  Ms. Salma
# 8    PH1009    Wahid Hasan    Male   22    Physics         4  3.10  Mr. Karim
# 9    PH1010   Yasmin Begum  Female   20    Physics         2  3.65  Ms. Salma
#
#      Location     Country  New_CGPA New Subject  Passed in DS
# ...
