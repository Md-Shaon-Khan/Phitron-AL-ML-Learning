# %%
import pandas as pd

data = {
    'Name':['S','A','R','T','Q'],
    'Exam_Score':[89,78,9,37,76],
    'Study_Hours':[6,4,0.2,1,4],
    'Passed':[True,True,False,True,True]
}

df = pd.DataFrame(data)
df
# Out:
#   Name  Exam_Score  Study_Hours  Passed
# 0    S          89          6.0    True
# 1    A          78          4.0    True
# 2    R           9          0.2   False
# 3    T          37          1.0    True
# 4    Q          76          4.0    True

# %%
df = pd.read_csv('student_performance_prediction.csv')

df
# Out:
#       Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 0         S00001                  12.5              NaN             75.0
# 1         S00002                   9.3             95.3             60.6
# 2         S00003                  13.2              NaN             64.0
# 3         S00004                  17.6             76.8             62.4
# 4         S00005                   8.8             89.3             72.7
# ...          ...                   ...              ...              ...
# 39995     S39996                  15.6             93.8             51.4
# 39996     S39997                  11.3             66.4             64.2
# 39997     S39998                  13.1             65.6             38.1
# 39998     S39999                  14.1             74.9              NaN
# 39999     S40000                  11.8             55.1             68.5
#
#       Participation in Extracurricular Activities Parent Education Level  \
# ...

# %%
df.head()
# Out:
#   Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 0     S00001                  12.5              NaN             75.0
# 1     S00002                   9.3             95.3             60.6
# 2     S00003                  13.2              NaN             64.0
# 3     S00004                  17.6             76.8             62.4
# 4     S00005                   8.8             89.3             72.7
#
#   Participation in Extracurricular Activities Parent Education Level Passed
# 0                                         Yes                 Master    Yes
# 1                                          No            High School     No
# 2                                          No              Associate     No
# 3                                         Yes               Bachelor     No
# 4                                          No                 Master     No

# %%
df.shape
# Out:
# (40000, 7)

# %%
df.columns.tolist()
# Out:
# ['Student ID',
#  'Study Hours per Week',
#  'Attendance Rate',
#  'Previous Grades',
#  'Participation in Extracurricular Activities',
#  'Parent Education Level',
#  'Passed']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=40000, step=1)

# %%
df.dtypes
# Out:
# Student ID                                      object
# Study Hours per Week                           float64
# Attendance Rate                                float64
# Previous Grades                                float64
# Participation in Extracurricular Activities     object
# Parent Education Level                          object
# Passed                                          object
# dtype: object

# %%
df
# Out:
#       Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 0         S00001                  12.5              NaN             75.0
# 1         S00002                   9.3             95.3             60.6
# 2         S00003                  13.2              NaN             64.0
# 3         S00004                  17.6             76.8             62.4
# 4         S00005                   8.8             89.3             72.7
# ...          ...                   ...              ...              ...
# 39995     S39996                  15.6             93.8             51.4
# 39996     S39997                  11.3             66.4             64.2
# 39997     S39998                  13.1             65.6             38.1
# 39998     S39999                  14.1             74.9              NaN
# 39999     S40000                  11.8             55.1             68.5
#
#       Participation in Extracurricular Activities Parent Education Level  \
# ...

# %%
df['Previous Grades'].head(5)
# Out:
# 0    75.0
# 1    60.6
# 2    64.0
# 3    62.4
# 4    72.7
# Name: Previous Grades, dtype: float64

# %%
df.Passed.head()
# Out:
# 0    Yes
# 1     No
# 2     No
# 3     No
# 4     No
# Name: Passed, dtype: object

# %%
df[['Previous Grades','Passed']].head()
# Out:
#    Previous Grades Passed
# 0             75.0    Yes
# 1             60.6     No
# 2             64.0     No
# 3             62.4     No
# 4             72.7     No

# %%
df.iloc[0]
# Out:
# Student ID                                     S00001
# Study Hours per Week                             12.5
# Attendance Rate                                   NaN
# Previous Grades                                  75.0
# Participation in Extracurricular Activities       Yes
# Parent Education Level                         Master
# Passed                                            Yes
# Name: 0, dtype: object

# %%
df.iloc[2]
# Out:
# Student ID                                        S00003
# Study Hours per Week                                13.2
# Attendance Rate                                      NaN
# Previous Grades                                     64.0
# Participation in Extracurricular Activities           No
# Parent Education Level                         Associate
# Passed                                                No
# Name: 2, dtype: object

# %%
df.iloc[0:3]
# Out:
#   Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 0     S00001                  12.5              NaN             75.0
# 1     S00002                   9.3             95.3             60.6
# 2     S00003                  13.2              NaN             64.0
#
#   Participation in Extracurricular Activities Parent Education Level Passed
# 0                                         Yes                 Master    Yes
# 1                                          No            High School     No
# 2                                          No              Associate     No

# %%
df.loc[0]
# Out:
# Student ID                                     S00001
# Study Hours per Week                             12.5
# Attendance Rate                                   NaN
# Previous Grades                                  75.0
# Participation in Extracurricular Activities       Yes
# Parent Education Level                         Master
# Passed                                            Yes
# Name: 0, dtype: object

# %%
df.loc[0, 'Passed']
# Out:
# 'Yes'

# %%
df['Grade'] = df['Previous Grades'].apply(
    lambda X: 'A' if X >= 90 else 'B'
)

# %%
df[['Grade','Previous Grades']].head(10)
# Out:
#   Grade  Previous Grades
# 0     B             75.0
# 1     B             60.6
# 2     B             64.0
# 3     B             62.4
# 4     B             72.7
# 5     B             69.3
# 6     A             93.6
# 7     B             59.2
# 8     A             91.9
# 9     B             37.8

# %%
df.shape
# Out:
# (40000, 8)

# %%
df = df.drop('Grade', axis = 1)
df.shape
# Out:
# (40000, 7)

# %%
df.shape
# Out:
# (40000, 7)
