# %%
import pandas as pd

data = {
"Name": ["Alice", "Bob", "Charlie", "Alice", "David", "Bob"],
"City": ["New York", "London", "Paris", "New York", "Tokyo", "London"],
"Score": [85, 90, 78, 85, 95, 90]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     85
# 4    David     Tokyo     95
# 5      Bob    London     90

# %%
unique_names = df['Name'].unique()

print(unique_names)
# Out:
# ['Alice' 'Bob' 'Charlie' 'David']

# %%
nunique_name = df['Name'].nunique()
nunique_name
# Out:
# 4

# %%
df.nunique()
# Out:
# Name     4
# City     4
# Score    4
# dtype: int64

# %%
unique_count = len(df['Name'].unique())
unique_count
# Out:
# 4

# %%
nunique_name_count = df['Name'].nunique()
nunique_name_count
# Out:
# 4

# %%
null_c = df.isnull()
null_c
# Out:
#     Name   City  Score
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False
# 4  False  False  False
# 5  False  False  False

# %%
notnull = df['Name'].notnull()
notnull
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# Name: Name, dtype: bool
