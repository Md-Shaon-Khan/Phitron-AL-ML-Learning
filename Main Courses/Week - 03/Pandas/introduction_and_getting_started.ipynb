# %%
import pandas as pd

pd.__version__
# Out:
# '2.3.3'

# %%
df = pd.read_csv('student_performance_prediction.csv')

df.head()
# Out:
#   Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 0     S00001                  12.5              NaN             75.0
# 1     S00002                   9.3             95.3             60.6
# 2     S00003                  13.2              NaN             64.0
# 3     S00004                  17.6             76.8             62.4
# 4     S00005                   8.8             89.3             72.7
#
#   Participation in Extracurricular Activities Parent Education Level Passed
# 0                                         Yes                 Master    Yes
# 1                                          No            High School     No
# 2                                          No              Associate     No
# 3                                         Yes               Bachelor     No
# 4                                          No                 Master     No

# %%
df.shape
# Out:
# (40000, 7)

# %%
df.columns.tolist()
# Out:
# ['Student ID',
#  'Study Hours per Week',
#  'Attendance Rate',
#  'Previous Grades',
#  'Participation in Extracurricular Activities',
#  'Parent Education Level',
#  'Passed']

# %%
df.columns
# Out:
# Index(['Student ID', 'Study Hours per Week', 'Attendance Rate',
#        'Previous Grades', 'Participation in Extracurricular Activities',
#        'Parent Education Level', 'Passed'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 7 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Student ID                                   40000 non-null  object
#  1   Study Hours per Week                         38005 non-null  float64
#  2   Attendance Rate                              38008 non-null  float64
#  3   Previous Grades                              38006 non-null  float64
#  4   Participation in Extracurricular Activities  38000 non-null  object
#  5   Parent Education Level                       38000 non-null  object
#  6   Passed                                       38000 non-null  object
# dtypes: float64(3), object(4)
# memory usage: 2.1+ MB

# %%
df.head()
# Out:
#   Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 0     S00001                  12.5              NaN             75.0
# 1     S00002                   9.3             95.3             60.6
# 2     S00003                  13.2              NaN             64.0
# 3     S00004                  17.6             76.8             62.4
# 4     S00005                   8.8             89.3             72.7
#
#   Participation in Extracurricular Activities Parent Education Level Passed
# 0                                         Yes                 Master    Yes
# 1                                          No            High School     No
# 2                                          No              Associate     No
# 3                                         Yes               Bachelor     No
# 4                                          No                 Master     No

# %%
df.tail(60)
# Out:
#       Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 39940     S39941                   7.8             96.0             60.1
# 39941     S39942                   9.9             77.3             61.9
# 39942     S39943                   8.0            102.7             47.9
# 39943     S39944                   9.9             72.4             50.8
# 39944     S39945                   NaN             79.9             68.2
# 39945     S39946                   3.0             90.0             45.8
# 39946     S39947                  13.2             79.0             64.1
# 39947     S39948                   9.0             85.5             64.4
# 39948     S39949                  16.8             80.7             73.8
# 39949     S39950                   NaN             46.7             79.4
# 39950     S39951                   8.0             90.3             72.5
# 39951     S39952                   9.4             98.6             97.5
# ...
