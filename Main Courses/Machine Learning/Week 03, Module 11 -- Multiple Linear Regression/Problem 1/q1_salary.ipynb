# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor

# %%
df = pd.read_csv("F:\Jupyter Projects\Phitron AL ML\Dataset\Salary Data.csv")
df.head(3)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\J'
# <>:1: SyntaxWarning: invalid escape sequence '\J'
# C:\Users\HP\AppData\Local\Temp\ipykernel_15052\1609581423.py:1: SyntaxWarning: invalid escape sequence '\J'
#   df = pd.read_csv("F:\Jupyter Projects\Phitron AL ML\Dataset\Salary Data.csv")
#     Age  Gender  ... Years of Experience    Salary
# 0  32.0    Male  ...                 5.0   90000.0
# 1  28.0  Female  ...                 3.0   65000.0
# 2  45.0    Male  ...                15.0  150000.0
#
# [3 rows x 6 columns]

# %%
col = ['Age', 'Years of Experience']

for i in col:
    plt.figure()
    sns.scatterplot( x = df[i], y = df['Salary'])

# %%
sns.countplot(data = df, x = df['Education Level'], hue = df['Salary'])
# Out:
# <Axes: xlabel='Education Level', ylabel='count'>

# %%
sns.scatterplot(data = df, x = 'Education Level', y = 'Salary')
# Out:
# <Axes: xlabel='Education Level', ylabel='Salary'>

# %%
average_salary = df['Salary'].groupby(df['Education Level']).mean()

# %%
average_salary
# Out:
# Education Level
# Bachelor's     74756.026786
# Master's      129795.918367
# PhD           157843.137255
# Name: Salary, dtype: float64

# %%
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder()
df['Education Level'] = encoder.fit_transform(df[['Education Level']])

# %%
col_corr = ['Years of Experience', 'Age', 'Education Level', 'Salary']

subset = df[col_corr]

corr_mat = subset.corr()

print(corr_mat)
# Out:
#                      Years of Experience       Age  Education Level    Salary
# Years of Experience             1.000000  0.979128         0.590863  0.930338
# Age                             0.979128  1.000000         0.562693  0.922335
# Education Level                 0.590863  0.562693         1.000000  0.670371
# Salary                          0.930338  0.922335         0.670371  1.000000

# %%
plt.figure(figsize = (8,6))
sns.heatmap(corr_mat, annot = True, fmt='.2f')
plt.show()
