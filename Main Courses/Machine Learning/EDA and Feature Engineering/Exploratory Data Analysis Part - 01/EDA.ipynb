# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('titanic_data_updated.csv')
df.head()
# Out:
#    PassengerId Survived Pclass  \
# 0            1       no  third
# 1            2      yes  first
# 2            3      yes  third
# 3            4      yes  first
# 4            5       no  third
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail(1)
# Out:
#      PassengerId Survived Pclass                 Name   Sex   Age  SibSp  \
# 890          891       no  third  Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 890      0  370376  7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.shape[0]
# Out:
# 891

# %%
df.shape[1]
# Out:
# 12

# %%
df.sample(5)
# Out:
#      PassengerId Survived  Pclass  \
# 119          120       no   third
# 41            42       no  second
# 363          364       no   third
# 341          342      yes   first
# 709          710      yes   third
#
#                                                   Name     Sex   Age  SibSp  \
# 119                  Andersson, Miss. Ellis Anna Maria  female   2.0      4
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 363                                    Asim, Mr. Adola    male  35.0      0
# 341                     Fortune, Miss. Alice Elizabeth  female  24.0      3
# 709  Moubarek, Master. Halim Gonios ("William George")    male   NaN      1
#
#      Parch              Ticket      Fare        Cabin Embarked
# 119      2              347082   31.2750          NaN        S
# 41       0               11668   21.0000          NaN        S
# 363      0  SOTON/O.Q. 3101310    7.0500          NaN        S
# 341      2               19950  263.0000  C23 C25 C27        S
# 709      1                2661   15.2458          NaN        C

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.Age.isnull().sum()
# Out:
# np.int64(177)

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.699118    0.523008    0.381594   32.204208
# std     257.353842   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000   38.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.sample(5)
# Out:
#      PassengerId Survived  Pclass                             Name     Sex  \
# 834          835       no   third           Allum, Mr. Owen George    male
# 791          792       no  second              Gaskell, Mr. Alfred    male
# 853          854      yes   first        Lines, Miss. Mary Conover  female
# 465          466       no   third  Goncalves, Mr. Manuel Estanslas    male
# 155          156       no   first      Williams, Mr. Charles Duane    male
#
#       Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# 834  18.0      0      0                2223   8.3000   NaN        S
# 791  16.0      0      0              239865  26.0000   NaN        S
# 853  16.0      0      1            PC 17592  39.4000   D28        S
# 465  38.0      0      0  SOTON/O.Q. 3101306   7.0500   NaN        S
# 155  51.0      0      1            PC 17597  61.3792   NaN        C

# %%
df.Survived.value_counts()
# Out:
# Survived
# no     549
# yes    342
# Name: count, dtype: int64

# %%
sns.countplot(data = df, x = 'Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df['Survived'].value_counts() / len(df) * 100
# Out:
# Survived
# no     61.616162
# yes    38.383838
# Name: count, dtype: float64

# %%
survived = df['Survived'].value_counts()

plt.pie(survived, autopct="%1.1f",labels = df['Survived'].unique())
# Out:
# ([<matplotlib.patches.Wedge at 0x146ebce1950>,
#   <matplotlib.patches.Wedge at 0x146ebce1d10>],
#  [Text(-0.39257494735793463, 1.0275626067091557, 'no'),
#   Text(0.3925749146953058, -1.0275626191877425, 'yes')],
#  [Text(-0.21413178946796432, 0.5604886945686304, '61.6'),
#   Text(0.21413177165198496, -0.5604887013751322, '38.4')])

# %%
pclass = df['Pclass'].value_counts()

sns.countplot(data = df, x = 'Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
plt.pie(pclass, autopct="%1.1f",labels = df['Pclass'].unique())
# Out:
# ([<matplotlib.patches.Wedge at 0x146ebd25590>,
#   <matplotlib.patches.Wedge at 0x146ebd25950>,
#   <matplotlib.patches.Wedge at 0x146ebd25d10>],
#  [Text(-0.17571619097547903, 1.085874679799225, 'third'),
#   Text(-0.5160760536623383, -0.9714244730478574, 'first'),
#   Text(0.8765111790709129, -0.6646263258130227, 'second')],
#  [Text(-0.09584519507753402, 0.5922952798904862, '55.1'),
#   Text(-0.2814960292703663, -0.5298678943897404, '24.2'),
#   Text(0.47809700676595246, -0.3625234504434669, '20.7')])

# %%
plt.hist(df['Age'],bins=50, edgecolor='black')

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.grid(alpha = 0.3)
plt.show()

# %%
sns.kdeplot(df['Age'])
plt.title('KDE Plot of Age')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>
