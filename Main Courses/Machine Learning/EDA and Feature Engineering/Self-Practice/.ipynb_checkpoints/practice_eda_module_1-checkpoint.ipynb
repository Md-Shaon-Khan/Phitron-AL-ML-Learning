# %%
import pandas as pd
df = pd.read_csv('titanic_data_updated.csv')
df.head(1)
# Out:
#    PassengerId Survived Pclass                     Name   Sex   Age  SibSp  \
# 0            1       no  third  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.shape
# Out:
# (344, 7)

# %%
df.shape[0]
# Out:
# 344

# %%
df.shape[1]
# Out:
# 7

# %%
df.head(7)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
# 5       3650.0    Male
# 6       3625.0  Female

# %%
df.sample(5)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 9       Adelie  Torgersen            42.0           20.2              190.0
# 181  Chinstrap      Dream            52.8           20.0              205.0
# 135     Adelie      Dream            41.1           17.5              190.0
# 164  Chinstrap      Dream            47.0           17.3              185.0
# 155  Chinstrap      Dream            45.4           18.7              188.0
#
#      body_mass_g     sex
# 9         4250.0     NaN
# 181       4550.0    Male
# 135       3900.0    Male
# 164       3700.0  Female
# 155       3525.0  Female

# %%
# Sample are not biased front or end

# %%
missing_value = pd.DataFrame(df.isnull().sum()).reset_index()
missing_value.columns = ['Column','Number']
missing_value
missing_value.sort_values(by = 'Number', ascending=False).head(1)
# Out:
#   Column  Number
# 6    sex      11

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.shape
# Out:
# (344, 7)

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df['body_mass_g'].max()
# Out:
# np.float64(6300.0)

# %%
df['flipper_length_mm'].mean()
# Out:
# np.float64(200.91520467836258)

# %%
sns.countplot(df['species'])
# Out:
# <Axes: xlabel='count', ylabel='species'>

# %%
sns.countplot(data=df, x='species')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.countplot(data=df, y='species')
# Out:
# <Axes: xlabel='count', ylabel='species'>

# %%
df['island'].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
df['island'].value_counts() / len(df) * 100
# Out:
# island
# Biscoe       48.837209
# Dream        36.046512
# Torgersen    15.116279
# Name: count, dtype: float64

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      168
# Female    165
# Name: count, dtype: int64

# %%
percentange = df['sex'].value_counts() / len(df) * 100

plt.pie(percentange, labels=percentange.index, autopct='%.1f%%%%')
plt.title('Pie chart based on percentage of sex')
plt.show()
