# %%
import numpy as np

# %%
arr = np.array([[10,20,30],[40,50,60]])

print(arr[:,1])
# Out:
# [20 50]

# %%
arr = np.array([1,2,3,4,5])

arr[1:4] = 0
print(arr)
# Out:
# [1 0 0 0 5]

# %%
arr = np.array([1,2,3])
print(arr.ndim)
# Out:
# 1
